# %% [markdown]
# # Return the root node of a binary search tree that matches the given preorder traversal.

# %% [markdown]
# ### Input: [8,5,1,7,10,12]
# ### Output: [8,5,10,1,7,null,12]
#          8
#         / \
#        5   10
#       / \   \
#      1   7   12

# %%
class TreeNode:
    def __init__(self,value):
        self.val = value
        self.left = None
        self.right = None

# %%
class Solution:
    def bstFromPreOrder(self,preorder):
        root = None
        for val in preorder:
            root = self.insertIntoBST(root,val)
        return root
    def insertIntoBST(self,root,val):
        if root == None:
            return TreeNode(val)
        elif val<root.val:
            root.left = self.insertIntoBST(root.left,val)
        else:
            root.right = self.insertIntoBST(root.right,val)
        return root

# %%
s = Solution()
preorder = [8,5,1,7,10,12]
print(s.bstFromPreOrder(preorder))

# %% [markdown]
# ### Above we have clearly programmed but if you want to see the nodes we can use _ _repr_ _

# %%
class TreeNode:
    def __init__(self,value):
        self.val = value
        self.left = None
        self.right = None
    def get_value(self):
        return self.val
    def  __repr__(self):
        return f"TreeNode({self.get_value()})"

# %%
class Solution:
    def bstFromPreOrder(self,preorder):
        root = None
        for val in preorder:
            root = self.insertIntoBST(root,val)
        return root
    def insertIntoBST(self,root,val):
        if root == None:
            return TreeNode(val)
        elif val<root.val:
            root.left = self.insertIntoBST(root.left,val)
        else:
            root.right = self.insertIntoBST(root.right,val)
        
        return root

# %%
s = Solution()
preorder = [8,5,1,7,10,12]
print(s.bstFromPreOrder(preorder))
# Out:
# TreeNode(8)

# %% [markdown]
# ### Recursion Understanding

# %%
from IPython.display import Image
Image('Call Stack Diagram.png')
